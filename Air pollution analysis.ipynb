# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\vardh\Downloads\air_data.csv")

# %%
data.head()
# Out:
#   IndicatorCode                                  Indicator ValueType  \
# 0        AIR_41  Ambient air pollution attributable deaths   numeric
# 1        AIR_41  Ambient air pollution attributable deaths   numeric
# 2        AIR_41  Ambient air pollution attributable deaths   numeric
# 3        AIR_41  Ambient air pollution attributable deaths   numeric
# 4        AIR_41  Ambient air pollution attributable deaths   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                AMR       Americas       Country                 ATG
# 1                AMR       Americas       Country                 ATG
# 2                AMR       Americas       Country                 ATG
# 3                AMR       Americas       Country                 BHS
# 4                AFR         Africa       Country                 COM
#
#               Location  Period  IsLatestYear  ... FactValue  \
# 0  Antigua and Barbuda    2019          True  ...     0.220
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IndicatorCode         249 non-null    object
#  1   Indicator             249 non-null    object
#  2   ValueType             249 non-null    object
#  3   ParentLocationCode    249 non-null    object
#  4   ParentLocation        249 non-null    object
#  5   Location type         249 non-null    object
#  6   SpatialDimValueCode   249 non-null    object
#  7   Location              249 non-null    object
#  8   Period                249 non-null    int64
#  9   IsLatestYear          249 non-null    bool
#  10  Dim1 type             249 non-null    object
#  11  Gender                249 non-null    object
#  12  FactValue             249 non-null    float64
#  13  FactValueNumericLow   249 non-null    float64
#  14  FactValueNumericHigh  249 non-null    float64
# ...

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['CO'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('CO')
plt.ylabel('TOTAL_CONCENTRATION')
plt.title('CONCENTARIONS OF EACH GAS')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['C6H6'], bins=5, color='skyblue', edgecolor='black')
plt.xlabel('C6H6')
plt.ylabel('TOTAL_CONCENTRATION')
plt.title('CONCENTARIONS OF EACH GAS')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['NMHC'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('NMHC')
plt.ylabel('TOTAL_CONCENTRATION')
plt.title('CONCENTARIONS OF EACH GAS')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['SO4'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('S04')
plt.ylabel('TOTAL_CONCENTRATION')
plt.title('CONCENTARIONS OF EACH GAS')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(data['NOX'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('NOX')
plt.ylabel('TOTAL_CONCENTRATION')
plt.title('CONCENTARIONS OF EACH GAS')
plt.show()

# %%
gender_counts = data['Gender'].value_counts()

# using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink','black'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Number of Males and Females')
plt.show()

# %%
# Alternatively, using Seaborn
plt.figure(figsize=(8, 6))
sns.countplot(x='Gender', data=data, palette=['black','blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Number of Males and Females')
plt.show()

# %%
country = data['ParentLocation'].value_counts()

# Plot the counts using Matplotlib
plt.figure(figsize=(20, 10))
plt.bar(country.index, country.values, color=['blue', 'pink','black'])
plt.xlabel('country')
plt.ylabel('Count')
plt.title('Number of countries')
plt.show()

# %%
total_concentration = data[['CO', 'C6H6', 'NMHC', 'SO4', 'NOX']].sum()

# %%
plt.figure(figsize=(5, 5))
plt.pie(total_concentration, labels=total_concentration.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of gases')
plt.show()
